# %% [markdown]
# # Data Loading, Storage, and File Formats

# %% [markdown]
# Input and output typically falls into a few main categories:
# - reading text files and other more efficient on-disk formats,
# - loading data from databases,
# - and interacting with network sources like web APIs.

# %% [markdown]
# ## Reading and Writing Data in Text Format

# %%
import pandas as pd
import requests

url = 'https://news.google.com/covid19/map?hl=en-IN&mid=/m/03rk0&gl=IN&ceid=IN:en'

header = {
  "User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.75 Safari/537.36",
  "X-Requested-With": "XMLHttpRequest"
}

r = requests.get(url, headers=header)

df = pd.read_html(r.text)

# %%
del df[0]['Cases per 1 million people']
df[0].columns
# Out:
# Index(['Location', 'Confirmed', 'Recovered', 'Deaths'], dtype='object')

# %%
deaths = df[0]['Deaths'][df[0]['Deaths']!='No data'].astype(int)
Confirmed = df[0]['Confirmed'][df[0]['Confirmed']!='No data'].astype(int)

# %%
#deaths/Confirmed * 100

# %%
df = pd.read_csv('data/ex1.csv')
df
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
pd.read_table('data/ex1.csv', sep=',')
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
pd.read_csv('data/ex1.csv',header=None,skiprows=1,names=['a', 'b', 'c', 'd', 'message'],index_col='message')
# Out:
#          a   b   c   d
# message
# hello    1   2   3   4
# world    5   6   7   8
# foo      9  10  11  12

# %%
pd.read_csv('data/ex2.csv', skiprows=[0, 2, 3])
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
sentinels = {'message': ['foo', 'NA'], 'something': ['two']}
pd.read_csv('data/ex3.csv', na_values=sentinels)
# Out:
#   something  a   b     c   d message
# 0       one  1   2   3.0   4     NaN
# 1       NaN  5   6   NaN   8   world
# 2     three  9  10  11.0  12     NaN

# %% [markdown]
# ## Reading Text Files in Pieces

# %% [markdown]
# When processing very large files or figuring out the right set of arguments to correctly process a large file, you may only want to read in a small piece of a file or iterate through smaller chunks of the file.

# %%
import numpy as np
dates = pd.date_range('1/1/2000',periods=7)
ts = pd.Series(np.arange(7), index=dates)
ts.to_csv('data/ts.csv')

# %% [markdown]
# ## JSON Data

# %%
obj = """
{"name": "Wes",
 "places_lived": ["United States", "Spain", "Germany"],
 "pet": null,
 "siblings": [{"name": "Scott", "age": 30, "pets": ["Zeus", "Zuko"]},
              {"name": "Katie", "age": 38,
               "pets": ["Sixes", "Stache", "Cisco"]}]
}
"""

# %%
import json
result = json.loads(obj)
result
# Out:
# {'name': 'Wes',
#  'places_lived': ['United States', 'Spain', 'Germany'],
#  'pet': None,
#  'siblings': [{'name': 'Scott', 'age': 30, 'pets': ['Zeus', 'Zuko']},
#   {'name': 'Katie', 'age': 38, 'pets': ['Sixes', 'Stache', 'Cisco']}]}

# %%
siblings = pd.DataFrame(result['siblings'], columns=['name', 'age'])
siblings
# Out:
#     name  age
# 0  Scott   30
# 1  Katie   38

# %% [markdown]
# ## Interacting with Web APIs

# %%
import requests
url = 'https://api.github.com/repos/pandas-dev/pandas/issues'
resp = requests.get(url)

data = resp.json()
#data

# %%
issues = pd.DataFrame(data, columns=['number', 'title','labels', 'state'])
issues
# Out:
#     number                                              title  \
# 0    35460  BUG: AssertionError: Number of Block dimension...
# 1    35459  CI: activate github actions on 1.1.x (PR only)...
# 2    35456        Add note about limited propagation of attrs
# 3    35455  REGR: DataFrame.to_numpy(dtype=str) raises Run...
# 4    35454                  DOC: update Python support policy
# 5    35451  WEB: Fixing whatsnew link in the home page (ve...
# 6    35450  BUG: dataframe.any() method behaves differentl...
# 7    35449  BUG: unique() casts its types' elements from `...
# 8    35447  Updated chunksize docstring for DataFrame.to_c...
# 9    35446  BUG: pd.testing.assert_frame_equal(..., check_...
# 10   35445        WIP: ENH: Add numba engine to groupby apply
# 11   35444  BUG: Attributes are lost when subsetting colum...
# 12   35443  BUG: Attributes of DataFrameGroupBy when subse...
# 13   35441  BUG: GroupBy.apply() throws erroneous ValueErr...
# 14   35440                       BUG: CategoricalIndex.format
# 15   35439  BUG: output of df.to_string depends on whether...
# 16   35438  DOC: Can't find mention of DataFrame accepting...
# 17   35437  BUG: tuple-of-tuples indexing results in NumPy...
# 18   35436  BUG: pd.read_parquet with pyarrow fails when r...
# 19   35434  BUG: Shift on a group column when column name ...
# 20   35432  CLN/PERF: move RangeIndex._cached_data to Rang...
# 21   35429  BUG: NA does not propagate through mask and wh...
# 22   35428      BUG: Inconsistent date parsing of to_datetime
# 23   35427  MAINT: Fix issue in StataReader due to upstrea...
# 24   35426  CI/COMPAT: read_stata failing in numpy dev pip...
# 25   35425            BUG: attrs lost for Series in DataFrame
# 26   35424  TST: adding test for .describe() with duplicat...
# 27   35423  TST: Add test for `GroupBy.describe()` with du...
# 28   35421                         Support reading YAML files
# 29   35420      to_json/read_json can't handle interval index
#
#                                                labels state
# 0   [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 1   [{'id': 48070600, 'node_id': 'MDU6TGFiZWw0ODA3...  open
# 2                                                  []  open
# 3   [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 4   [{'id': 134699, 'node_id': 'MDU6TGFiZWwxMzQ2OT...  open
# 5   [{'id': 1508144531, 'node_id': 'MDU6TGFiZWwxNT...  open
# 6   [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 7   [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 8                                                  []  open
# 9   [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 10                                                 []  open
# 11  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 12  [{'id': 1741841389, 'node_id': 'MDU6TGFiZWwxNz...  open
# 13                                                 []  open
# 14                                                 []  open
# 15  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 16  [{'id': 134699, 'node_id': 'MDU6TGFiZWwxMzQ2OT...  open
# 17  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 18  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 19  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 20                                                 []  open
# 21  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 22                                                 []  open
# 23  [{'id': 104865385, 'node_id': 'MDU6TGFiZWwxMDQ...  open
# 24  [{'id': 48070600, 'node_id': 'MDU6TGFiZWw0ODA3...  open
# 25  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 26  [{'id': 697792067, 'node_id': 'MDU6TGFiZWw2OTc...  open
# 27  [{'id': 697792067, 'node_id': 'MDU6TGFiZWw2OTc...  open
# 28  [{'id': 76812, 'node_id': 'MDU6TGFiZWw3NjgxMg=...  open
# 29  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open

# %% [markdown]
# <hr/>
